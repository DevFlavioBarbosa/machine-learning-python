# %% [markdown]
# # Aprendizado de máquina supervisionado e não supervisionado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Modelo balanceado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Underfitting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Overfitting

# %% [markdown]
# ![image.png](data:image/png;base64,...)
