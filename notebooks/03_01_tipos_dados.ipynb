# %% [markdown]
# # Tipos de dados

# %%
import pandas as pd

# %%
df = pd.read_csv('../conjuntos de dados/02_01_tiny_data.csv')

# %%
df.head()
# Out:
#     produto  <R$2,49  R$2,50-4,99  R$5,00-9,99
# 0     blusa      418          869          400
# 1      meia      320          670           32
# 2  encharpe       15           58            5
# 3   bermuda       95          120           44
# 4     lenço      224          350           10

# %%
colunas_valores = [col for col in df.columns if col != 'produtos']

# %%
colunas_valores
# Out:
# ['produto', '<R$2,49', 'R$2,50-4,99', 'R$5,00-9,99']

# %%
df_long = pd.melt(
    df,                        # DataFrame original
    id_vars=['produto'],      # Coluna que permanecerá como identificador
    value_vars=colunas_valores,  # Colunas que serão transformadas
    var_name='valor',          # Nome da nova coluna que armazenará os nomes das colunas originais
    value_name='qnt_produto'   # Nome da nova coluna que armazenará os valores
)

# %%
df_long.sort_values(['produto', 'valor'])
# Out:
#      produto        valor  qnt_produto
# 3    bermuda      <R$2,49           95
# 8    bermuda  R$2,50-4,99          120
# 13   bermuda  R$5,00-9,99           44
# 0      blusa      <R$2,49          418
# 5      blusa  R$2,50-4,99          869
# 10     blusa  R$5,00-9,99          400
# 2   encharpe      <R$2,49           15
# 7   encharpe  R$2,50-4,99           58
# 12  encharpe  R$5,00-9,99            5
# 4      lenço      <R$2,49          224
# 9      lenço  R$2,50-4,99          350
# 14     lenço  R$5,00-9,99           10
# 1       meia      <R$2,49          320
# 6       meia  R$2,50-4,99          670
# 11      meia  R$5,00-9,99           32

# %%
df_long
# Out:
#      produto        valor  qnt_produto
# 0      blusa      <R$2,49          418
# 1       meia      <R$2,49          320
# 2   encharpe      <R$2,49           15
# 3    bermuda      <R$2,49           95
# 4      lenço      <R$2,49          224
# 5      blusa  R$2,50-4,99          869
# 6       meia  R$2,50-4,99          670
# 7   encharpe  R$2,50-4,99           58
# 8    bermuda  R$2,50-4,99          120
# 9      lenço  R$2,50-4,99          350
# 10     blusa  R$5,00-9,99          400
# 11      meia  R$5,00-9,99           32
# 12  encharpe  R$5,00-9,99            5
# 13   bermuda  R$5,00-9,99           44
# 14     lenço  R$5,00-9,99           10

# %%
item = df_long['produto'][3]
qnt = df_long['qnt_produto'][3]

# %%
print(f'Dado: {qnt}')
# Out:
# Dado: 95

# %%
print(f'Informação: Existem {qnt} unidades de {item} no estoque.')
# Out:
# Informação: Existem 95 unidades de bermuda no estoque.

# %%
[1.1, 1.2, 1.3, 1.4]
# Out:
# [1.1, 1.2, 1.3, 1.4]

# %%
['Muito Insatisfeito', 'Insatisfeito', 'Neutro', 'Satisfeito', 'Muito Satisfeito']
# Out:
# ['Muito Insatisfeito',
#  'Insatisfeito',
#  'Neutro',
#  'Satisfeito',
#  'Muito Satisfeito']
