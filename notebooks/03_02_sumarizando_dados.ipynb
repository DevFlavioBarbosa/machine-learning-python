# %%
import requests
import pandas as pd

# %%
# Request URL
url_base = 'https://dadosabertos.camara.leg.br/api/v2/proposicoes?dataApresentacaoInicio=2025-01-01&dataApresentacaoFim=2025-06-30&ordem=ASC&ordenarPor=id'

# %%
# Coleta dados
dados = requests.get(url_base).json()

# %%
dados
# Out:
# {'dados': [{'id': 2481874,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/2481874',
#    'siglaTipo': 'PL',
#    'codTipo': 139,
#    'numero': 1,
#    'ano': 2025,
#    'ementa': 'Dispõe sobre a criação de oito varas federais no Estado de Santa Catarina, a transformação de cargos de juiz federal substituto na Justiça Federal da 4ª Região e a criação de cargos de juízes federais e dá outras providências.'},
#   {'id': 2481875,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/2481875',
#    'siglaTipo': 'PL',
#    'codTipo': 139,
#    'numero': 2,
#    'ano': 2025,
#    'ementa': 'Dispõe sobre a reestruturação de cargos da magistratura no quadro permanente da Justiça Federal da 1ª Região e sobre a criação da 2ª Turma Recursal dos Juizados Especiais Federais da Seção Judiciária do Piauí.'},
#   {'id': 2481876,
#    'uri': 'https://dadosabertos.camara.leg.br/api/v2/proposicoes/2481876',
#    'siglaTipo': 'TVR',
#    'codTipo': 425,
# ...

# %%
# Requisita os dados em formato json das primeiras 81 páginas

# Lista para armazenar todos os dados
lista_dados = []
offset = 1

# Loop para coletar todas as páginas
for offset in range(1,82):
    # URL com paginação
    url = f"{url_base}&pagina={offset}&itens=15"

    # Faz a requisição
    response = requests.get(url).json()
    records = response['dados']

    # # Adiciona os dados à lista
    lista_dados.extend(records)

    # # Próxima página
    offset += 1

# %%
# Verifica a quantidade de registros coletados
len(lista_dados)
# Out:
# 1215

# %%
# Cria dataframe pandas com os dados
df_proposicoes = pd.DataFrame.from_dict(data=lista_dados)

# %%
df_proposicoes.head()
# Out:
#         id                                                uri siglaTipo  \
# 0  2481874  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 1  2481875  https://dadosabertos.camara.leg.br/api/v2/prop...        PL
# 2  2481876  https://dadosabertos.camara.leg.br/api/v2/prop...       TVR
# 3  2481877  https://dadosabertos.camara.leg.br/api/v2/prop...       MSC
# 4  2481880  https://dadosabertos.camara.leg.br/api/v2/prop...       MPV
#
#    codTipo  numero   ano                                             ementa
# 0      139       1  2025  Dispõe sobre a criação de oito varas federais ...
# 1      139       2  2025  Dispõe sobre a reestruturação de cargos da mag...
# 2      425       1  2025  Submete à apreciação do Congresso Nacional o a...
# 3      401    1632  2025  Submete à apreciação do Congresso Nacional o a...
# 4      291    1287  2025  Institui apoio financeiro à pessoa com deficiê...

# %%
# Sumarização simples
df_proposicoes.describe()
# Out:
#                  id      codTipo       numero          ano
# count  1.215000e+03  1215.000000  1215.000000  1215.000000
# mean   2.482521e+06   272.193416   107.344033  1991.646091
# std    3.661548e+02   178.422770   132.575726   257.763892
# min    2.481874e+06   133.000000     1.000000     0.000000
# 25%    2.482212e+06   139.000000    32.000000  2025.000000
# 50%    2.482522e+06   148.000000    84.000000  2025.000000
# 75%    2.482828e+06   401.000000   157.500000  2025.000000
# max    2.483165e+06  1097.000000  2940.000000  2025.000000

# %%
# !pip install ydata-profiling
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 24.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.0/679.0 kB 32.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 8.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.5 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=a7dbd905b94c908aedca1c6ee027f0b7a0ed97a2d89cde35880ddb8de98b7d4d
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
profile = ProfileReport(df_proposicoes, title="Introdução - Pandas Profiling Report")

# %%
profile.to_notebook_iframe()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
